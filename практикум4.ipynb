# %% [markdown]
# <a href="https://colab.research.google.com/github/MaksimSmolenkov/3/blob/main/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D1%83%D0%BC4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Инициализация библиотек

# %%
import numpy
import numpy as np
import matplotlib.pyplot as plt
import pandas
import scipy
import sympy
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## 1 задание

# %%
def f(x):         #1 задание
  return 2/(sympy.tan(x))

d = (6 - 4)/30
p = [4+d*i for i in range(30)][1:]
dots = []

for i in range(29):
  dots.append(f(p[i]))
  print(f(p[i]))
# Out:
# 1.50695285961889
# 1.30763914107546
# 1.12499873644504
# 0.955580123781177
# 0.796636255852563
# 0.645927280764001
# 0.501580551642110
# 0.361988146307152
# 0.225729178436688
# 0.0915084033448925
# -0.0418948320214609
# -0.175671736705646
# -0.311026943824889
# -0.449222414364185
# -0.591625831065491
# -0.739767551756898
# -0.895411413922800
# -1.06064678762367
# -1.23801277226581
# -1.43067125297864
# -1.64265539155395
# -1.87923729638894
# -2.14748957507639
# -2.45717366317437
# -2.82220267685539
# -3.26316674834820
# -3.81194732258330
# -4.52076117731762
# -5.48154324288379

# %% [markdown]
# ## 2 задание

# %%
plt.plot(p, dots) #2
plt.legend([r'$y = \frac{2}{tg(x)}$'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('График функции ' r'$y = \frac{2}{tg(x)}$', fontsize=15)
plt.show()

# %% [markdown]
# ## 3 задание

# %%
#3
plt.plot(p, dots, 'o', color=(0.3, 0.5, 0.11))
plt.xlabel('x')
plt.ylabel('y')
plt.axis((4, 6, -6, 2))
plt.grid(visible=True, which='major', axis='both', color = 'blue', linewidth=0.4, alpha = 0.7)
plt.title('График функции ' r'$y = \frac{2}{tg(x)}$', fontsize=15)
plt.show()

# %% [markdown]
# ## 4 задание

# %% [markdown]
# ### гистограмма равномерного распределения

# %%
#4.1
uniform_sample = numpy.round(numpy.random.uniform(low = 0, high = 100, size = 100))#4
normal_sample = numpy.random.normal(loc = 50, scale = 10, size = 100).astype(int)

plt.hist(uniform_sample, 10, facecolor='g', alpha=0.75)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Histogram of uniform sample')

plt.axis([0, 100, 0, 20])
plt.grid(True)
plt.show()

# %% [markdown]
# ### гистограмма равномерного распределения

# %%
#4.2
plt.hist(normal_sample, 15, facecolor='r', alpha=0.75)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Histogram of normal sample')

plt.axis([0, 100, 0, 25])
plt.grid(True)
plt.show()

# %% [markdown]
# # 5 задание

# %% [markdown]
# ## Столбцевая диаграмма

# %%
#5.1
vals = [1, 2, 3, 4, 5]
data = numpy.round(numpy.random.uniform(low = 1, high = 5, size = 50))#4
data2 = [numpy.sum(data==1), numpy.sum(data==2), numpy.sum(data==3), numpy.sum(data==4), numpy.sum(data==5)]
print('1 встречается: ', numpy.sum(data==1))
print('2 встречается: ', numpy.sum(data==2))
print('3 встречается: ', numpy.sum(data==3))
print('4 встречается: ', numpy.sum(data==4))
print('5 встречается: ', numpy.sum(data==5))

plt.bar(vals, data2, color = ['b', 'r', 'g', 'y', 'c'])
plt.title('Распределение цифр от 1 до 5', fontsize = 15)
# Out:
# 1 встречается:  4
# 2 встречается:  14
# 3 встречается:  17
# 4 встречается:  10
# 5 встречается:  5
# Text(0.5, 1.0, 'Распределение цифр от 1 до 5')

# %% [markdown]
# ## Круговая диаграмма

# %%
#5.2
fig, ax = plt.subplots()
ax.pie(data2, labels=vals, colors = ['b', 'r', 'g', 'y', 'c'])
plt.title('Распределение цифр от 1 до 5', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Распределение цифр от 1 до 5')

# %%
#6
e=2.7
fig=plt.figure()
ax=fig.add_subplot(1,1,1,projection="3d")
x,y=np.meshgrid(np.linspace(-5,5,100), np.linspace(-5,5,100))
z=(x - 1.5)**2 + (y - 2)**2
ax.plot_surface(x,y,z)
plt.show()
