# %% [markdown]
# <a href="https://colab.research.google.com/github/MaksimSmolenkov/3/blob/main/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D1%83%D0%BC5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings

# %% [markdown]
# ##1

# %%
listName = ["Strom, Mrs. Wilhelm (Elna Matilda Persson)", "Navratil, Mr. Michel (\"Louis M Hoffman\")", "Minahan, Miss. Daisy E"]
listAge = [
  29, 36.5, 33
]
listSex = [
  "female", "male", "female"
]
columns = ['Name', 'Age', 'Sex']
df1 = pd.DataFrame(zip(listName, listAge, listSex), columns=columns)
df1
# Out:
#                                          Name   Age     Sex
# 0  Strom, Mrs. Wilhelm (Elna Matilda Persson)  29.0  female
# 1    Navratil, Mr. Michel ("Louis M Hoffman")  36.5    male
# 2                      Minahan, Miss. Daisy E  33.0  female

# %% [markdown]
# ##2

# %%
df2 = pd.read_csv('titanic_csv.csv', delimiter=';')
df2 = df2.rename (
    columns = {
        'PassengerId' : 'passengerid',
        'Pclass' : 'pclass',
        'Survived' : 'survived',
        'Name' : 'name',
        'Sex'  : 'sex',
        'Age' : 'age',
        'SibSp'      : 'sibsp',
        'Parch' : 'parch',
        'Ticket' : 'ticket',
        'Fare' : 'fare',
        'Cabin' : 'cabin',
        'Embarked' : 'embarked'
    }
)
df2
# Out:
#      passengerid  survived  pclass                                  name  \
# 0            454         1       1              Goldenberg, Mr. Samuel L
# 1            234         1       3        Asplund, Miss. Lillian Gertrud
# 2            556         0       1                    Wright, Mr. George
# 3            766         1       1  Hogeboom, Mrs. John C (Anna Andrews)
# 4            444         1       2             Reynaldo, Ms. Encarnacion
# ..           ...       ...     ...                                   ...
# 489          363         0       3       Barbara, Mrs. (Catherine David)
# 490          447         1       2     Mellinger, Miss. Madeleine Violet
# 491           95         0       3                     Coxon, Mr. Daniel
# 492           59         1       2          West, Miss. Constance Mirium
# 493           33         1       3              Glynn, Miss. Mary Agatha
#
#         sex   age  sibsp  parch      ticket     fare cabin embarked
# ...

# %% [markdown]
# ##3

# %%
df3 = pd.read_csv('https://gist.githubusercontent.com/zaryanezrya/8b4ef51c707cb16d5e88a44dc00a1bb2/raw/41230f49c6268e072dbf102672f670be256922ab/gistfile1.txt')
df3
# Out:
#      passengerid  survived  pclass  \
# 0            552         0       2
# 1            689         0       3
# 2            605         1       1
# 3            305         0       3
# 4            290         1       3
# ..           ...       ...     ...
# 495          482         0       2
# 496          155         0       3
# 497          851         0       3
# 498          850         1       1
# 499           77         0       3
#
#                                              name     sex   age  sibsp  parch  \
# 0                     Sharp, Mr. Percival James R    male  27.0      0      0
# 1                 Fischer, Mr. Eberhard Thelander    male  18.0      0      0
# 2                 Homer, Mr. Harry ("Mr E Haven")    male  35.0      0      0
# 3               Williams, Mr. Howard Hugh "Harry"    male   NaN      0      0
# 4                            Connolly, Miss. Kate  female  22.0      0      0
# ...

# %%
df = pd.merge(df2, df3, how = 'outer')
df
# Out:
#      passengerid  survived  pclass  \
# 0            454         1       1
# 1            234         1       3
# 2            556         0       1
# 3            766         1       1
# 4            444         1       2
# ..           ...       ...     ...
# 889          445         1       3
# 890          640         0       3
# 891          851         0       3
# 892          850         1       1
# 893           77         0       3
#
#                                              name     sex   age  sibsp  parch  \
# 0                        Goldenberg, Mr. Samuel L    male  49.0      1      0
# 1                  Asplund, Miss. Lillian Gertrud  female   5.0      4      2
# 2                              Wright, Mr. George    male  62.0      0      0
# 3            Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1      0
# 4                       Reynaldo, Ms. Encarnacion  female  28.0      0      0
# ...

# %%
df = df.set_index('passengerid')
# Out:
#              survived  pclass                                          name  \
# passengerid
# 454                 1       1                      Goldenberg, Mr. Samuel L
# 234                 1       3                Asplund, Miss. Lillian Gertrud
# 556                 0       1                            Wright, Mr. George
# 766                 1       1          Hogeboom, Mrs. John C (Anna Andrews)
# 444                 1       2                     Reynaldo, Ms. Encarnacion
# ...               ...     ...                                           ...
# 445                 1       3             Johannesen-Bratthammer, Mr. Bernt
# 640                 0       3                    Thorneycroft, Mr. Percival
# 851                 0       3       Andersson, Master. Sigvard Harald Elias
# 850                 1       1  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 77                  0       3                             Staneff, Mr. Ivan
#
# ...

# %%
df.sort_values
# Out:
# <bound method DataFrame.sort_values of              survived  pclass                                          name  \
# passengerid
# 454                 1       1                      Goldenberg, Mr. Samuel L
# 234                 1       3                Asplund, Miss. Lillian Gertrud
# 556                 0       1                            Wright, Mr. George
# 766                 1       1          Hogeboom, Mrs. John C (Anna Andrews)
# 444                 1       2                     Reynaldo, Ms. Encarnacion
# ...               ...     ...                                           ...
# 445                 1       3             Johannesen-Bratthammer, Mr. Bernt
# 640                 0       3                    Thorneycroft, Mr. Percival
# 851                 0       3       Andersson, Master. Sigvard Harald Elias
# 850                 1       1  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 77                  0       3                             Staneff, Mr. Ivan
#
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 894 entries, 454 to 77
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  894 non-null    int64
#  1   pclass    894 non-null    int64
#  2   name      894 non-null    object
#  3   sex       894 non-null    object
#  4   age       716 non-null    float64
#  5   sibsp     894 non-null    int64
#  6   parch     894 non-null    int64
#  7   ticket    894 non-null    object
#  8   fare      894 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  892 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.8+ KB
#          survived      pclass         age       sibsp       parch        fare
# count  894.000000  894.000000  716.000000  894.000000  894.000000  894.000000
# mean     0.382550    2.310962   29.685992    0.522371    0.380313   32.121914
# ...

# %%
df.iloc[0, :] = df.iloc[2, :]
df
# Out:
#              survived  pclass                                          name  \
# passengerid
# 454                 0       1                            Wright, Mr. George
# 234                 1       3                Asplund, Miss. Lillian Gertrud
# 556                 0       1                            Wright, Mr. George
# 766                 1       1          Hogeboom, Mrs. John C (Anna Andrews)
# 444                 1       2                     Reynaldo, Ms. Encarnacion
# ...               ...     ...                                           ...
# 445                 1       3             Johannesen-Bratthammer, Mr. Bernt
# 640                 0       3                    Thorneycroft, Mr. Percival
# 851                 0       3       Andersson, Master. Sigvard Harald Elias
# 850                 1       1  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 77                  0       3                             Staneff, Mr. Ivan
#
# ...

# %%
def f(x):
  if x == "female":
    return "f"
  else:
    return "m"

df['sex'] = df['sex'].map(f)
df
# Out:
#              survived  pclass                                          name  \
# passengerid
# 454                 0       1                            Wright, Mr. George
# 234                 1       3                Asplund, Miss. Lillian Gertrud
# 556                 0       1                            Wright, Mr. George
# 766                 1       1          Hogeboom, Mrs. John C (Anna Andrews)
# 444                 1       2                     Reynaldo, Ms. Encarnacion
# ...               ...     ...                                           ...
# 445                 1       3             Johannesen-Bratthammer, Mr. Bernt
# 640                 0       3                    Thorneycroft, Mr. Percival
# 851                 0       3       Andersson, Master. Sigvard Harald Elias
# 850                 1       1  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 77                  0       3                             Staneff, Mr. Ivan
#
# ...

# %%
count_pass = df.groupby('ticket').agg({'name': 'size'})
cm6 = count_pass[count_pass['name'] >=6].index
for i in cm6:
  print(count_pass.loc[i, ['name']])
# Out:
# name    7
# Name: 1601, dtype: int64
# name    6
# Name: 3101295, dtype: int64
# name    7
# Name: 347082, dtype: int64
# name    6
# Name: 347088, dtype: int64
# name    6
# Name: CA 2144, dtype: int64
# name    7
# Name: CA. 2343, dtype: int64
